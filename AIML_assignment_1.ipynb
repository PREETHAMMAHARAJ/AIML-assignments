# %%
#Lists
l1=[1,2,3]
l2=[4,5,6]
print(l1+l2)
# 1. Lists
list1 = [1, 2, 3, 4, 5]
list2 = [6, 7, 8, 9, 10]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
import numpy as np
A=np.array(l1)
B=np.array(l2)
print(A+B)
print(A-B)
print(A*B)
print(A/B)
# Out:
# [5 7 9]
# [-3 -3 -3]
# [ 4 10 18]
# [0.25 0.4  0.5 ]
# [1 2 3]

# %%
x=[1,2,3,4,5]
y=[9,8,7,6,5]
import matplotlib.pyplot as plt
plt.title('shashi')
plt.xlabel('x-axis')
plt.xlabel('y-axis')
print(plt.scatter(y,x))
# Out:
# <matplotlib.collections.PathCollection object at 0x78714306e6e0>

# %%
print(plt.bar(y,x))
# Out:
# <BarContainer object of 5 artists>

# %%
import pandas as pd
pd.read_csv('/content/sample_data/california_housing_test.csv')
x=pd.read_csv('/content/sample_data/california_housing_test.csv')
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
plt.bar(x["longitude"],x["latitude"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-179d8ff1800f> in <cell line: 1>()
# ----> 1 plt.bar(x["longitude"],x["latitude"])
#
# TypeError: list indices must be integers or slices, not str
